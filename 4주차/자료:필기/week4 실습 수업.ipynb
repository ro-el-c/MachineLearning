# %% [markdown]
# ## SVM
#
# DNN 나오기 전, SVM이 가장 인기 많았음
#
#
# 정의 한 줄에 나오는 term 들은 다 알아야 함
#
# linear separable 않은 문제들 -> 직선의 방정식 찾는 문제로 바꿈
#
# 1. 벡터 공간에서 선을 찾는 문제로 바꿈
# 2. **마진**(support vectors로 부터의 거리) **최대**로 하는
#
#
# **kernel function**: 고차원으로 사상시키는 함수
# <br>; 대체로 잘 알려진 함수들 사용
#
#
# **support vector**: 경계에 존재하는 점
#
# 고차원으로 사상 후, 내적 -> 너무 복잡
#
# => 따라서, '마치 이와 같은 효과를 내는' --> **커널 트릭**
#
# <br>
# -----
# <br>
#
# ### mail 받았을 때, spam / ham 분류
