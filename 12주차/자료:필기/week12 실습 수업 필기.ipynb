# %% [markdown]
# # RNN
# : 시간 축에 따라 들어오는 정보 다루는 데에 용이
#
# <br>
#
# RNN이 깊다 == time이 깊다
#
# gate function ; gate - sigmoid(1: 열려있음, 0: 닫혀있음)
# - forget gate
# - input gate
# - output gate
#
# -> 곱하기가 아닌 '**더하기**'가 들어가기 때문에 vanish gradient 문제가 해결
#
# encoder - decoder: seq2seq model
#
# <br>
#
# **매우 중요** Attention
# - 꼭 알기
# - 어떻게 계산되는지
# - seq2seq에서 왜, 어떻게 - 꼭 알기
#
# <br>
#
# 이번주
# - gate
# - attention
